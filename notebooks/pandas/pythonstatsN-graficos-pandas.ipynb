# %% [markdown]
# # Gráficos con PANDAS
# #### Como debuxar gráficos de distintos tipos con PANDAS
#
# AVISO: Exemplo simple por rematar

# %%
import pandas as pd

notas_df = pd.read_csv('https://raw.githubusercontent.com/jfsanchez/bigdata/refs/heads/main/datasets/sint%C3%A9ticos/notas_estudantes.csv')

# %% [markdown]
# ## Histogramas

# %%
notas_df[['Nota_Matematicas']].plot.hist(bins=10, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Bibliografía
#
#  - <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html>
